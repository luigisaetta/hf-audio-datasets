# %% [markdown]
# ### Test loading HF audio dataset from a local directory

# %%
import os
import random
import glob
from os import path
import pandas as pd
from datasets import load_dataset, load_from_disk, Audio
from datasets import Dataset

# to play audio
import IPython

# %%
# this is the local directory
HF_DIR = "atco2_hf_augmented"

SAMPLING_RATE = 16000

# %%
# load the dataset from local directory
loaded_ds = load_from_disk(HF_DIR)

# %%
loaded_ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['path', 'audio', 'sentence'],
#         num_rows: 1512
#     })
#     test: Dataset({
#         features: ['path', 'audio', 'sentence'],
#         num_rows: 56
#     })
# })

# %%
INDEX = random.randint(0, len(loaded_ds["train"]))

print(loaded_ds["train"][INDEX]["sentence"])
IPython.display.Audio(loaded_ds["train"][INDEX]["audio"]["array"], rate=SAMPLING_RATE)
# Out:
# runway three four left cleared to land Quantas One Forty Six
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
